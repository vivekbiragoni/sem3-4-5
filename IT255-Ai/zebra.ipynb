# %%
from constraint import Problem

def solve_zebra_puzzle():
    problem = Problem()

    # Define variables
    variables = ['House1_Color', 'House2_Color', 'House3_Color', 'House4_Color', 'House5_Color']

    # Define domain for each variable
    domain = ['Red', 'Green', 'Blue', 'Ivory', 'Yellow']

    # Assign domain to variables
    problem.addVariables(variables, domain)

    # Define constraints
    problem.addConstraint(lambda h1, h2: h1 != h2, ('House1_Color', 'House2_Color'))
    problem.addConstraint(lambda h1, h3: h1 != h3, ('House1_Color', 'House3_Color'))
    problem.addConstraint(lambda h1, h4: h1 != h4, ('House1_Color', 'House4_Color'))
    problem.addConstraint(lambda h1, h5: h1 != h5, ('House1_Color', 'House5_Color'))
    problem.addConstraint(lambda h2, h3: h2 != h3, ('House2_Color', 'House3_Color'))
    problem.addConstraint(lambda h2, h4: h2 != h4, ('House2_Color', 'House4_Color'))
    problem.addConstraint(lambda h2, h5: h2 != h5, ('House2_Color', 'House5_Color'))
    problem.addConstraint(lambda h3, h4: h3 != h4, ('House3_Color', 'House4_Color'))
    problem.addConstraint(lambda h3, h5: h3 != h5, ('House3_Color', 'House5_Color'))
    problem.addConstraint(lambda h4, h5: h4 != h5, ('House4_Color', 'House5_Color'))

    # Additional constraints based on the given puzzle
    problem.addConstraint(lambda h1: h1 == 'Red', ('House1_Color',))
    problem.addConstraint(lambda h2: h2 == 'Spaniard', ('House2_Color',))  # Spaniard owns the dog
    problem.addConstraint(lambda h1: h1 == 'Norwegian', ('House1_Color',))  # Norwegian lives in the first house
    problem.addConstraint(lambda h4, h5: h4 == 'Ivory' and h5 == 'Green', ('House4_Color', 'House5_Color'))  # Green is to the right of Ivory
    problem.addConstraint(lambda h1, h2: abs(h1 - h2) == 1, ('House1_Color', 'House2_Color'))  # Hershey bars and fox are next to each other
    problem.addConstraint(lambda h3: h3 == 'Yellow', ('House3_Color',))  # Kit Kats are eaten in the yellow house
    problem.addConstraint(lambda h3, h4: abs(h3 - h4) == 1, ('House3_Color', 'House4_Color'))  # Norwegian lives next to the blue house
    problem.addConstraint(lambda h3: h3 == 'Smarties', ('House3_Color',))  # Smarties eater owns snails
    problem.addConstraint(lambda h2: h2 == 'Snickers', ('House2_Color',))  # Snickers eater drinks orange juice
    problem.addConstraint(lambda h2: h2 == 'Ukrainian', ('House2_Color',))  # Ukrainian drinks tea
    problem.addConstraint(lambda h3: h3 == 'Japanese', ('House3_Color',))  # Japanese eats Milky Ways
    problem.addConstraint(lambda h3, h4: abs(h3 - h4) == 1, ('House3_Color', 'House4_Color'))  # Kit Kats and horse are next to each other
    problem.addConstraint(lambda h4: h4 == 'Green', ('House4_Color',))  # Coffee is drunk in the green house
    problem.addConstraint(lambda h3: h3 == 'Milk', ('House3_Color',))  # Milk is drunk in the middle house

    # Solve the problem
    solutions = problem.getSolutions()

    # Print the solutions
    for solution in solutions:
        zebra_house = None
        water_house = None
        for house, color in solution.items():
            if color == 'Zebra':
                zebra_house = house
            if color == 'Water':
                water_house = house
        if zebra_house and water_house:
            return f"The Zebra lives in {zebra_house} and water is drunk in {water_house}."

    return "No solution found."

# Solve the Zebra puzzle
result = solve_zebra_puzzle()

# Print the result
print(result)
# Out:
# No solution found.

# %%
from constraint import Problem

def solve_zebra_puzzle():
    problem = Problem()

    # Define variables
    variables = ['House1_Color', 'House2_Color', 'House3_Color', 'House4_Color', 'House5_Color']

    # Define domain for each variable
    domain = ['Red', 'Green', 'Blue', 'Ivory', 'Yellow']

    # Assign domain to variables
    problem.addVariables(variables, domain)

    # Define constraints
    problem.addConstraint(lambda h1, h2: h1 != h2, ('House1_Color', 'House2_Color'))
    problem.addConstraint(lambda h1, h3: h1 != h3, ('House1_Color', 'House3_Color'))
    problem.addConstraint(lambda h1, h4: h1 != h4, ('House1_Color', 'House4_Color'))
    problem.addConstraint(lambda h1, h5: h1 != h5, ('House1_Color', 'House5_Color'))
    problem.addConstraint(lambda h2, h3: h2 != h3, ('House2_Color', 'House3_Color'))
    problem.addConstraint(lambda h2, h4: h2 != h4, ('House2_Color', 'House4_Color'))
    problem.addConstraint(lambda h2, h5: h2 != h5, ('House2_Color', 'House5_Color'))
    problem.addConstraint(lambda h3, h4: h3 != h4, ('House3_Color', 'House4_Color'))
    problem.addConstraint(lambda h3, h5: h3 != h5, ('House3_Color', 'House5_Color'))
    problem.addConstraint(lambda h4, h5: h4 != h5, ('House4_Color', 'House5_Color'))

    # Additional constraints based on the given puzzle
    problem.addConstraint(lambda h1: h1 == 'Red', ('House1_Color',))
    problem.addConstraint(lambda h2: h2 == 'Spaniard', ('House2_Color',))  # Spaniard owns the dog
    problem.addConstraint(lambda h1: h1 == 'Norwegian', ('House1_Color',))  # Norwegian lives in the first house
    problem.addConstraint(lambda h4, h5: h4 == 'Ivory' and h5 == 'Green', ('House4_Color', 'House5_Color'))  # Green is to the right of Ivory
    problem.addConstraint(lambda h1, h2: abs(h1 - h2) == 1, ('House1_Color', 'House2_Color'))  # Hershey bars and fox are next to each other
    problem.addConstraint(lambda h3: h3 == 'Yellow', ('House3_Color',))  # Kit Kats are eaten in the yellow house
    problem.addConstraint(lambda h3, h4: abs(h3 - h4) == 1, ('House3_Color', 'House4_Color'))  # Norwegian lives next to the blue house
    problem.addConstraint(lambda h3: h3 == 'Smarties', ('House3_Color',))  # Smarties eater owns snails
    problem.addConstraint(lambda h2: h2 == 'Snickers', ('House2_Color',))  # Snickers eater drinks orange juice
    problem.addConstraint(lambda h2: h2 == 'Ukrainian', ('House2_Color',))  # Ukrainian drinks tea
    problem.addConstraint(lambda h3: h3 == 'Japanese', ('House3_Color',))  # Japanese eats Milky Ways
    problem.addConstraint(lambda h3, h4: abs(h3 - h4) == 1, ('House3_Color', 'House4_Color'))  # Kit Kats and horse are next to each other
    problem.addConstraint(lambda h4: h4 == 'Green', ('House4_Color',))  # Coffee is drunk in the green house
    problem.addConstraint(lambda h3: h3 == 'Milk', ('House3_Color',))  # Milk is drunk in the middle house

    # Solve the problem
    solutions = problem.getSolutions()

    # Print the solutions
    for solution in solutions:
        zebra_house = None
        water_house = None
        for house, color in solution.items():
            if color == 'Zebra':
                zebra_house = house
            if color == 'Water':
                water_house = house
        if zebra_house and water_house:
            return f"The Zebra lives in {zebra_house} and water is drunk in {water_house}."

    return "No solution found."

# Solve the Zebra puzzle
result = solve_zebra_puzzle()

# Print the result
print(result)
# Out:
# No solution found.

# %%
from constraint import Problem, AllDifferentConstraint

def solve_zebra_puzzle():
    problem = Problem()

    # Define variables
    attributes = ['house_number', 'color', 'nationality', 'candy', 'drink', 'pet']
    houses = range(1, 6)

    # Assign domains to variables
    for attribute in attributes:
        problem.addVariable(attribute, houses)

    # Add constraints
    problem.addConstraint(AllDifferentConstraint(), attributes)

    problem.addConstraint(lambda h, c: h == c, ['nationality', 'color'])  # The Englishman lives in the red house.
    problem.addConstraint(lambda s, p: s == p, ['nationality', 'pet'])  # The Spaniard owns the dog.
    problem.addConstraint(lambda h: h == 1, ['house_number'])  # The Norwegian lives in the first house on the left.
    problem.addConstraint(lambda g, i: g == i + 1, ['color', 'color'])  # The green house is immediately to the right of the ivory house.
    problem.addConstraint(lambda h, f: abs(h - f) == 1, ['candy', 'pet'])  # The man who eats Hershey bars lives in the house next to the man with the fox.
    problem.addConstraint(lambda c: c == 'Yellow', ['candy'])  # Kit Kats are eaten in the yellow house.
    problem.addConstraint(lambda n, b: abs(n - b) == 1, ['nationality', 'color'])  # The Norwegian lives next to the blue house.
    problem.addConstraint(lambda c, p: c == p, ['candy', 'pet'])  # The Smarties eater owns snails.
    problem.addConstraint(lambda c, d: c == d, ['candy', 'drink'])  # The Snickers eater drinks orange juice.
    problem.addConstraint(lambda n, d: n == d, ['nationality', 'drink'])  # The Ukrainian drinks tea.
    problem.addConstraint(lambda n, c: n == c, ['nationality', 'candy'])  # The Japanese eats Milky Ways.
    problem.addConstraint(lambda c, h, p: abs(c - h) == 1 and abs(c - p) == 1, ['candy', 'house_number', 'pet'])  # Kit Kats are eaten in a house next to the house where the horse is kept.
    problem.addConstraint(lambda g, c: g == c, ['drink', 'color'])  # Coffee is drunk in the green house.
    problem.addConstraint(lambda h: h == 3, ['house_number'])  # Milk is drunk in the middle house.

    # Find a solution
    solution = problem.getSolution()
    return solution

# Solve the puzzle
solution = solve_zebra_puzzle()

# Print the solution
for house in range(1, 6):
    print(f"House {house}")
    for attribute in solution:
        if solution[attribute] == house:
            print(f"{attribute}: {solution[attribute]}")
# Out:
# House 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\vivek\Desktop\sem4\IT255-Ai\zebra.ipynb Cell 3 in 4
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W2sZmlsZQ%3D%3D?line=39'>40</a> for house in range(1, 6):
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W2sZmlsZQ%3D%3D?line=40'>41</a>     print(f"House {house}")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W2sZmlsZQ%3D%3D?line=41'>42</a>     for attribute in solution:
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W2sZmlsZQ%3D%3D?line=42'>43</a>         if solution[attribute] == house:
# ...

# %%
from constraint import Problem, AllDifferentConstraint

def solve_zebra_puzzle():
    problem = Problem()

    # Define variables
    attributes = ['house_number', 'color', 'nationality', 'candy', 'drink', 'pet']
    houses = range(1, 6)

    # Assign domains to variables
    for attribute in attributes:
        problem.addVariable(attribute, houses)

    # Add constraints
    problem.addConstraint(AllDifferentConstraint(), attributes)

    problem.addConstraint(lambda h, c: h == c, ['nationality', 'color'])  # The Englishman lives in the red house.
    problem.addConstraint(lambda s, p: s == p, ['nationality', 'pet'])  # The Spaniard owns the dog.
    problem.addConstraint(lambda h: h == 1, ['house_number'])  # The Norwegian lives in the first house on the left.
    problem.addConstraint(lambda g, i: g == i + 1, ['color', 'color'])  # The green house is immediately to the right of the ivory house.
    problem.addConstraint(lambda h, f: abs(h - f) == 1, ['candy', 'pet'])  # The man who eats Hershey bars lives in the house next to the man with the fox.
    problem.addConstraint(lambda c: c == 'Yellow', ['candy'])  # Kit Kats are eaten in the yellow house.
    problem.addConstraint(lambda n, b: abs(n - b) == 1, ['nationality', 'color'])  # The Norwegian lives next to the blue house.
    problem.addConstraint(lambda c, p: c == p, ['candy', 'pet'])  # The Smarties eater owns snails.
    problem.addConstraint(lambda c, d: c == d, ['candy', 'drink'])  # The Snickers eater drinks orange juice.
    problem.addConstraint(lambda n, d: n == d, ['nationality', 'drink'])  # The Ukrainian drinks tea.
    problem.addConstraint(lambda n, c: n == c, ['nationality', 'candy'])  # The Japanese eats Milky Ways.
    problem.addConstraint(lambda c, h, p: abs(c - h) == 1 and abs(c - p) == 1, ['candy', 'house_number', 'pet'])  # Kit Kats are eaten in a house next to the house where the horse is kept.
    problem.addConstraint(lambda g, c: g == c, ['drink', 'color'])  # Coffee is drunk in the green house.
    problem.addConstraint(lambda h: h == 3, ['house_number'])  # Milk is drunk in the middle house.

    # Find a solution
    solution = problem.getSolution()
    return solution

# Solve the puzzle
solution = solve_zebra_puzzle()

# Check if a solution exists
if solution is not None:
    # Print the solution
    for house in range(1, 6):
        print(f"House {house}")
        for attribute in solution:
            if solution[attribute] == house:
                print(f"{attribute}: {solution[attribute]}")
else:
    print("No solution found.")
# Out:
# No solution found.

# %%
from constraint import Problem

def solve_zebra_puzzle():
    problem = Problem()

    # Define variables
    colors = ["Red", "Green", "Ivory", "Yellow", "Blue"]
    nationalities = ["Englishman", "Spaniard", "Norwegian", "Ukrainian", "Japanese"]
    candies = ["Hershey", "Kit Kat", "Smarties", "Snickers", "Milky Way"]
    drinks = ["Water", "Orange Juice", "Tea", "Coffee", "Milk"]
    pets = ["Dog", "Fox", "Horse", "Snails", "Zebra"]

    # Assign variables to the houses
    for i in range(1, 6):
        problem.addVariable(f"House{i}_Color", colors)
        problem.addVariable(f"House{i}_Nationality", nationalities)
        problem.addVariable(f"House{i}_Candy", candies)
        problem.addVariable(f"House{i}_Drink", drinks)
        problem.addVariable(f"House{i}_Pet", pets)

    # Define constraints
    problem.addConstraint(lambda a, b: a == "Red", ("House1_Nationality", "House1_Color"))
    problem.addConstraint(lambda a, b: a == "Spaniard", ("House2_Nationality", "House2_Pet"))
    problem.addConstraint(lambda a: a == "Norwegian", ("House1_Nationality",))
    problem.addConstraint(lambda a, b: a == "Green" and b == "Ivory", ("House2_Color", "House3_Color"))
    problem.addConstraint(lambda a, b: abs(ord(a) - ord(b)) == 1, ("House1_Candy", "House1_Pet"))
    problem.addConstraint(lambda a: a == "Kit Kat", ("HouseX_Candy",), ("HouseX_Color",), "X == 'Yellow'")
    problem.addConstraint(lambda a, b: abs(ord(a) - ord(b)) == 1, ("HouseX_Color", "HouseY_Color"), ("HouseX_Nationality",), ("HouseY_Color",), "X == 'Norwegian', Y == 'Blue'")
    problem.addConstraint(lambda a: a == "Smarties", ("HouseX_Candy",), ("HouseX_Pet",), "X == 'Snails'")
    problem.addConstraint(lambda a: a == "Snickers", ("HouseX_Candy",), ("HouseX_Drink",), "X == 'Orange Juice'")
    problem.addConstraint(lambda a: a == "Ukrainian", ("HouseX_Nationality",), ("HouseX_Drink",), "X == 'Tea'")
    problem.addConstraint(lambda a: a == "Japanese", ("HouseX_Nationality",), ("HouseX_Candy",), "X == 'Milky Way'")
    problem.addConstraint(lambda a, b: abs(ord(a) - ord(b)) == 1, ("HouseX_Candy", "HouseY_Pet"), ("HouseX_Candy",), ("HouseY_Pet",), "X == 'Kit Kat', Y == 'Horse'")
    problem.addConstraint(lambda a: a == "Coffee", ("HouseX_Drink",), ("HouseX_Color",), "X == 'Green'")
    problem.addConstraint(lambda a: a == "Milk", ("House3_Drink",))

    # Solve the problem
    solution = problem.getSolution()
    return solution

solution = solve_zebra_puzzle()
if solution:
    print("Zebra lives in the", solution["HouseX_Pet"], "house.")
    print("Water is drunk in the", solution["HouseX_Drink"], "house.")
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\vivek\Desktop\sem4\IT255-Ai\zebra.ipynb Cell 5 in 4
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W4sZmlsZQ%3D%3D?line=37'>38</a>     solution = problem.getSolution()
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W4sZmlsZQ%3D%3D?line=38'>39</a>     return solution
# ---> <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W4sZmlsZQ%3D%3D?line=40'>41</a> solution = solve_zebra_puzzle()
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W4sZmlsZQ%3D%3D?line=41'>42</a> if solution:
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W4sZmlsZQ%3D%3D?line=42'>43</a>     print("Zebra lives in the", solution["HouseX_Pet"], "house.")
#
# ...

# %%
import nltk
from nltk.sem import Expression
from nltk.inference import Prover9

# Define the knowledge base
knowledge_base = nltk.LogicParser().parse(
    """
    # Define predicates
    House(x, c)
    Color(x, y)
    Nationality(x, y)
    Candy(x, y)
    Drink(x, y)
    Pet(x, y)

    # Given facts
    House(x, r) -> Nationality(x, e)
    Pet(x, d) -> Nationality(x, s)
    House(n, 1)
    (Color(x, g) & Color(x + 1, i)) -> House(x, y)
    (Candy(x, h) & Pet(x, f)) -> (House(x - 1, y) | House(x + 1, y))
    Candy(x, k) -> Color(x, y)
    (Nationality(x, n) & Color(x, b)) -> (House(x - 1, y) | House(x + 1, y))
    Candy(x, s) -> Pet(x, n)
    Candy(x, sn) -> Drink(x, o)
    Nationality(x, u) -> Drink(x, t)
    Nationality(x, j) -> Candy(x, mw)
    (Candy(x, k) & Pet(h, h)) -> (House(x - 1, y) | House(x + 1, y))
    Drink(x, c) -> Color(x, g)
    Drink(m, k)
    """
)

# Create an instance of the Prover9 inference engine
prover = Prover9()

# Convert the knowledge base into clauses
clauses = knowledge_base.to_cnf()

# Query for the zebra's house and the house where they drink water
query = nltk.LogicParser().parse("House(z, zebra) & Drink(w, water)")

# Perform the inference
result = prover.prove(query, [clauses])

# Check if the query is satisfied
if result:
    model = result.model()
    zebra_house = model.evaluate(Expression.fromstring('House(z, zebra)')).simplify()
    water_house = model.evaluate(Expression.fromstring('House(w, water)')).simplify()
    print("The zebra lives in house", zebra_house)
    print("They drink water in house", water_house)
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\vivek\Desktop\sem4\IT255-Ai\zebra.ipynb Cell 6 in 6
#       <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> from nltk.inference import Prover9
#       <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> # Define the knowledge base
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> knowledge_base = nltk.LogicParser().parse(
#       <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a>     """
#       <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a>     # Define predicates
# ...

# %%
from constraint import Problem

def solve_zebra_puzzle():
    problem = Problem()

    # Define variables
    colors = ["Red", "Green", "Ivory", "Yellow", "Blue"]
    nationalities = ["Englishman", "Spaniard", "Norwegian", "Ukrainian", "Japanese"]
    candies = ["Hershey", "Kit Kat", "Smarties", "Snickers", "Milky Way"]
    drinks = ["Water", "Orange Juice", "Tea", "Coffee", "Milk"]
    pets = ["Dog", "Fox", "Horse", "Snails", "Zebra"]

    # Assign variables to the houses
    for i in range(1, 6):
        problem.addVariable(f"House{i}_Color", colors)
        problem.addVariable(f"House{i}_Nationality", nationalities)
        problem.addVariable(f"House{i}_Candy", candies)
        problem.addVariable(f"House{i}_Drink", drinks)
        problem.addVariable(f"House{i}_Pet", pets)

    # Define constraints
    problem.addConstraint(lambda a, b: a == "Red", ("House1_Color",))
    problem.addConstraint(lambda a, b: a == "Spaniard", ("House2_Nationality",))
    problem.addConstraint(lambda a: a == "Norwegian", ("House1_Nationality",))
    problem.addConstraint(lambda a, b: a == "Green" and b == "Ivory", ("House2_Color", "House3_Color"))
    problem.addConstraint(lambda a, b: abs(ord(a) - ord(b)) == 1, ("House1_Candy", "House2_Pet"))
    problem.addConstraint(lambda a: a == "Kit Kat", ("HouseX_Candy",), "X == 'Yellow'")
    problem.addConstraint(lambda a, b: abs(ord(a) - ord(b)) == 1, ("HouseX_Color", "HouseY_Color"), "X == 'Norwegian'", "Y == 'Blue'")
    problem.addConstraint(lambda a: a == "Smarties", ("HouseX_Candy",), "X == 'Snails'")
    problem.addConstraint(lambda a: a == "Snickers", ("HouseX_Candy",), ("HouseX_Drink",), "X == 'Orange Juice'")
    problem.addConstraint(lambda a: a == "Ukrainian", ("HouseX_Nationality",), ("HouseX_Drink",), "X == 'Tea'")
    problem.addConstraint(lambda a: a == "Japanese", ("HouseX_Nationality",), ("HouseX_Candy",), "X == 'Milky Way'")
    problem.addConstraint(lambda a, b: abs(ord(a) - ord(b)) == 1, ("HouseX_Candy", "HouseY_Pet"), "X == 'Kit Kat'", "Y == 'Horse'")
    problem.addConstraint(lambda a: a == "Coffee", ("HouseX_Drink",), ("HouseX_Color",), "X == 'Green'")
    problem.addConstraint(lambda a: a == "Milk", ("House3_Drink",))

    # Solve the problem
    solution = problem.getSolution()
    return solution

solution = solve_zebra_puzzle()
if solution:
    print("Zebra lives in the", solution["HouseX_Pet"], "house.")
    print("Water is drunk in the", solution["HouseX_Drink"], "house.")
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\vivek\Desktop\sem4\IT255-Ai\zebra.ipynb Cell 7 in 4
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W6sZmlsZQ%3D%3D?line=37'>38</a>     solution = problem.getSolution()
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W6sZmlsZQ%3D%3D?line=38'>39</a>     return solution
# ---> <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W6sZmlsZQ%3D%3D?line=40'>41</a> solution = solve_zebra_puzzle()
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W6sZmlsZQ%3D%3D?line=41'>42</a> if solution:
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#W6sZmlsZQ%3D%3D?line=42'>43</a>     print("Zebra lives in the", solution["HouseX_Pet"], "house.")
#
# ...

# %%
from nltk.sem.logic import Expression, Variable
from nltk.inference import Prover9

# Define the knowledge base
knowledge_base = [
    # Given facts
    Expression.fromstring('House(x, r) -> Nationality(x, e)'),
    Expression.fromstring('Pet(x, d) -> Nationality(x, s)'),
    Expression.fromstring('House(n, 1)'),
    Expression.fromstring('(Color(x, g) & Color(x + 1, i)) -> House(x, y)'),
    Expression.fromstring('(Candy(x, h) & Pet(x, f)) -> (House(x - 1, y) | House(x + 1, y))'),
    Expression.fromstring('Candy(x, k) -> Color(x, y)'),
    Expression.fromstring('(Nationality(x, n) & Color(x, b)) -> (House(x - 1, y) | House(x + 1, y))'),
    Expression.fromstring('Candy(x, s) -> Pet(x, n)'),
    Expression.fromstring('Candy(x, sn) -> Drink(x, o)'),
    Expression.fromstring('Nationality(x, u) -> Drink(x, t)'),
    Expression.fromstring('Nationality(x, j) -> Candy(x, mw)'),
    Expression.fromstring('(Candy(x, k) & Pet(h, h)) -> (House(x - 1, y) | House(x + 1, y))'),
    Expression.fromstring('Drink(x, c) -> Color(x, g)'),
    Expression.fromstring('Drink(m, k)')
]

# Create an instance of the Prover9 inference engine
prover = Prover9()

# Query for the zebra's house and the house where they drink water
query = Expression.fromstring('House(z, zebra) & Drink(w, water)')

# Perform the inference
result = prover.prove(query, knowledge_base)

# Check if the query is satisfied
if result:
    model = result.model()
    zebra_house = model.get('z')
    water_house = model.get('w')
    print("The zebra lives in house", zebra_house)
    print("They drink water in house", water_house)
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# UnexpectedTokenException                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:154, in LogicParser.parse(self, data, signature)
#     153 try:
# --> 154     result = self.process_next_expression(None)
#     155     if self.inRange(0):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:290, in LogicParser.process_next_expression(self, context)
#     286     raise ExpectedMoreTokensException(
#     287         self._currentIndex + 1, message="Expression expected."
#     288     ) from e
# --> 290 accum = self.handle(tok, context)
#     292 if not accum:
#
# ...

# %%
from constraint import Problem

def solve_zebra_puzzle():
    problem = Problem()

    # Define variables
    colors = ["Red", "Green", "Ivory", "Yellow", "Blue"]
    nationalities = ["Englishman", "Spaniard", "Norwegian", "Ukrainian", "Japanese"]
    candies = ["Hershey", "Kit Kat", "Smarties", "Snickers", "Milky Way"]
    drinks = ["Water", "Orange Juice", "Tea", "Coffee", "Milk"]
    pets = ["Dog", "Fox", "Horse", "Snails", "Zebra"]

    # Assign variables to the houses
    for i in range(1, 6):
        problem.addVariable(f"House{i}_Color", colors)
        problem.addVariable(f"House{i}_Nationality", nationalities)
        problem.addVariable(f"House{i}_Candy", candies)
        problem.addVariable(f"House{i}_Drink", drinks)
        problem.addVariable(f"House{i}_Pet", pets)

    # Define constraints
    problem.addConstraint(lambda a: a == "Red", ("House1_Color",))
    problem.addConstraint(lambda a: a == "Spaniard", ("House2_Nationality",))
    problem.addConstraint(lambda a: a == "Norwegian", ("House1_Nationality",))
    problem.addConstraint(lambda a, b: a == "Green" and b == "Ivory", ("House2_Color", "House3_Color"))
    problem.addConstraint(lambda a, b: abs(ord(a) - ord(b)) == 1, ("House1_Candy", "House2_Pet"))
    problem.addConstraint(lambda a: a == "Kit Kat", ("HouseX_Candy",), "X == 'Yellow'")
    problem.addConstraint(lambda a, b: abs(ord(a) - ord(b)) == 1, ("HouseX_Color", "HouseY_Color"), "X == 'Norwegian'", "Y == 'Blue'")
    problem.addConstraint(lambda a: a == "Smarties", ("HouseX_Candy",), "X == 'Snails'")
    problem.addConstraint(lambda a: a == "Snickers", ("HouseX_Candy",), ("HouseX_Drink",), "X == 'Orange Juice'")
    problem.addConstraint(lambda a: a == "Ukrainian", ("HouseX_Nationality",), ("HouseX_Drink",), "X == 'Tea'")
    problem.addConstraint(lambda a: a == "Japanese", ("HouseX_Nationality",), ("HouseX_Candy",), "X == 'Milky Way'")
    problem.addConstraint(lambda a, b: abs(ord(a) - ord(b)) == 1, ("HouseX_Candy", "HouseY_Pet"), "X == 'Kit Kat'", "Y == 'Horse'")
    problem.addConstraint(lambda a: a == "Coffee", ("HouseX_Drink",), ("HouseX_Color",), "X == 'Green'")
    problem.addConstraint(lambda a: a == "Milk", ("House3_Drink",))

    # Solve the problem
    solution = problem.getSolution()
    return solution

solution = solve_zebra_puzzle()
if solution:
    print("Zebra lives in the", solution["HouseX_Pet"], "house.")
    print("Water is drunk in the", solution["HouseX_Drink"], "house.")
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\vivek\Desktop\sem4\IT255-Ai\zebra.ipynb Cell 9 in 4
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X11sZmlsZQ%3D%3D?line=37'>38</a>     solution = problem.getSolution()
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X11sZmlsZQ%3D%3D?line=38'>39</a>     return solution
# ---> <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X11sZmlsZQ%3D%3D?line=40'>41</a> solution = solve_zebra_puzzle()
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X11sZmlsZQ%3D%3D?line=41'>42</a> if solution:
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X11sZmlsZQ%3D%3D?line=42'>43</a>     print("Zebra lives in the", solution["HouseX_Pet"], "house.")
#
# ...

# %%
from nltk.sem.logic import Expression, Variable
from nltk.inference import Prover9

# Define the knowledge base
knowledge_base = [
    # Given facts
    Expression.fromstring('House(x, r) -> Nationality(x, e)'),
    Expression.fromstring('Pet(x, d) -> Nationality(x, s)'),
    Expression.fromstring('House(n, 1)'),
    Expression.fromstring('Color(x, g) & Color(y, i) & (x + 1 = y) -> House(x, y)'),
    Expression.fromstring('(Candy(x, h) & Pet(x, f)) -> (House(x - 1, y) | House(x + 1, y))'),
    Expression.fromstring('Candy(x, k) -> Color(x, y)'),
    Expression.fromstring('(Nationality(x, n) & Color(x, b)) -> (House(x - 1, y) | House(x + 1, y))'),
    Expression.fromstring('Candy(x, s) -> Pet(x, n)'),
    Expression.fromstring('Candy(x, sn) -> Drink(x, o)'),
    Expression.fromstring('Nationality(x, u) -> Drink(x, t)'),
    Expression.fromstring('Nationality(x, j) -> Candy(x, mw)'),
    Expression.fromstring('(Candy(x, k) & Pet(h, h)) -> (House(x - 1, y) | House(x + 1, y))'),
    Expression.fromstring('Drink(x, c) -> Color(x, g)'),
    Expression.fromstring('Drink(m, k)')
]

# Create an instance of the Prover9 inference engine
prover = Prover9()

# Query for the zebra's house and the house where they drink water
query = Expression.fromstring('House(z, zebra) & Drink(w, water)')

# Perform the inference
result = prover.prove(query, knowledge_base)

# Check if the query is satisfied
if result:
    model = result.model()
    zebra_house = model.get('z')
    water_house = model.get('w')
    print("The zebra lives in house", zebra_house)
    print("They drink water in house", water_house)
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# UnexpectedTokenException                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:154, in LogicParser.parse(self, data, signature)
#     153 try:
# --> 154     result = self.process_next_expression(None)
#     155     if self.inRange(0):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:297, in LogicParser.process_next_expression(self, context)
#     293     raise UnexpectedTokenException(
#     294         self._currentIndex, tok, message="Expression expected."
#     295     )
# --> 297 return self.attempt_adjuncts(accum, context)
#
# ...

# %%
from constraint import Problem

def solve_zebra_puzzle():
    problem = Problem()

    # Define variables
    colors = ["Red", "Green", "Ivory", "Yellow", "Blue"]
    nationalities = ["Englishman", "Spaniard", "Norwegian", "Ukrainian", "Japanese"]
    candies = ["Hershey", "Kit Kat", "Smarties", "Snickers", "Milky Way"]
    drinks = ["Water", "Orange Juice", "Tea", "Coffee", "Milk"]
    pets = ["Dog", "Fox", "Horse", "Snails", "Zebra"]

    # Assign variables to the houses
    for i in range(1, 6):
        problem.addVariable(f"House{i}_Color", colors)
        problem.addVariable(f"House{i}_Nationality", nationalities)
        problem.addVariable(f"House{i}_Candy", candies)
        problem.addVariable(f"House{i}_Drink", drinks)
        problem.addVariable(f"House{i}_Pet", pets)

    # Define constraints
    problem.addConstraint(lambda a: a == "Red", ("House1_Color",))
    problem.addConstraint(lambda a: a == "Spaniard", ("House2_Nationality",))
    problem.addConstraint(lambda a: a == "Norwegian", ("House1_Nationality",))
    problem.addConstraint(lambda a, b: a == "Green" and b == "Ivory", ("House2_Color", "House3_Color"))
    problem.addConstraint(lambda a, b: abs(ord(a) - ord(b)) == 1, ("House1_Candy", "House2_Pet"))
    problem.addConstraint(lambda a: a == "Kit Kat", ("HouseX_Candy",), "X == 'Yellow'")
    problem.addConstraint(lambda a, b: abs(ord(a) - ord(b)) == 1, ("HouseX_Color", "HouseY_Color"), "X == 'Norwegian'", "Y == 'Blue'")
    problem.addConstraint(lambda a: a == "Smarties", ("HouseX_Candy",), "X == 'Snails'")
    problem.addConstraint(lambda a: a == "Snickers", ("HouseX_Candy",), ("HouseX_Drink",), "X == 'Orange Juice'")
    problem.addConstraint(lambda a: a == "Ukrainian", ("HouseX_Nationality",), ("HouseX_Drink",), "X == 'Tea'")
    problem.addConstraint(lambda a: a == "Japanese", ("HouseX_Nationality",), ("HouseX_Candy",), "X == 'Milky Way'")
    problem.addConstraint(lambda a, b: abs(ord(a) - ord(b)) == 1, ("HouseX_Candy", "HouseY_Pet"), "X == 'Kit Kat'", "Y == 'Horse'")
    problem.addConstraint(lambda a: a == "Coffee", ("HouseX_Drink",), ("HouseX_Color",), "X == 'Green'")
    problem.addConstraint(lambda a: a == "Milk", ("House3_Drink",))

    # Solve the problem
    solution = problem.getSolution()
    return solution

solution = solve_zebra_puzzle()
if solution:
    print("Zebra lives in the", solution["HouseX_Pet"], "house.")
    print("Water is drunk in the", solution["HouseX_Drink"], "house.")
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\vivek\Desktop\sem4\IT255-Ai\zebra.ipynb Cell 11 in 4
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X13sZmlsZQ%3D%3D?line=37'>38</a>     solution = problem.getSolution()
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X13sZmlsZQ%3D%3D?line=38'>39</a>     return solution
# ---> <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X13sZmlsZQ%3D%3D?line=40'>41</a> solution = solve_zebra_puzzle()
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X13sZmlsZQ%3D%3D?line=41'>42</a> if solution:
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X13sZmlsZQ%3D%3D?line=42'>43</a>     print("Zebra lives in the", solution["HouseX_Pet"], "house.")
#
# ...

# %%
from nltk.sem.logic import Expression, Variable
from nltk.inference import Prover9

# Define the knowledge base
knowledge_base = [
    # Given facts
    Expression.fromstring('House(x, r) -> Nationality(x, e)'),
    Expression.fromstring('Pet(x, d) -> Nationality(x, s)'),
    Expression.fromstring('House(n, 1)'),
    Expression.fromstring('Color(x, g) & Color(y, i) & Adjacent(x, y) -> House(x, y)'),
    Expression.fromstring('(Candy(x, h) & Pet(x, f)) -> (House(x - 1, y) | House(x + 1, y))'),
    Expression.fromstring('Candy(x, k) -> Color(x, y)'),
    Expression.fromstring('(Nationality(x, n) & Color(x, b)) -> (House(x - 1, y) | House(x + 1, y))'),
    Expression.fromstring('Candy(x, s) -> Pet(x, n)'),
    Expression.fromstring('Candy(x, sn) -> Drink(x, o)'),
    Expression.fromstring('Nationality(x, u) -> Drink(x, t)'),
    Expression.fromstring('Nationality(x, j) -> Candy(x, mw)'),
    Expression.fromstring('(Candy(x, k) & Pet(h, h)) -> (House(x - 1, y) | House(x + 1, y))'),
    Expression.fromstring('Drink(x, c) -> Color(x, g)'),
    Expression.fromstring('Drink(m, k)'),
    # Additional statements for adjacency
    Expression.fromstring('Adjacent(x, y) -> (x + 1 = y)'),
    Expression.fromstring('Adjacent(y, x) -> (y + 1 = x)')
]

# Create an instance of the Prover9 inference engine
prover = Prover9()

# Query for the zebra's house and the house where they drink water
query = Expression.fromstring('House(z, zebra) & Drink(w, water)')

# Perform the inference
result = prover.prove(query, knowledge_base)

# Check if the query is satisfied
if result:
    model = result.model()
    zebra_house = model.get('z')
    water_house = model.get('w')
    print("The zebra lives in house", zebra_house)
    print("They drink water in house", water_house)
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# UnexpectedTokenException                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:154, in LogicParser.parse(self, data, signature)
#     153 try:
# --> 154     result = self.process_next_expression(None)
#     155     if self.inRange(0):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:297, in LogicParser.process_next_expression(self, context)
#     293     raise UnexpectedTokenException(
#     294         self._currentIndex, tok, message="Expression expected."
#     295     )
# --> 297 return self.attempt_adjuncts(accum, context)
#
# ...

# %%
from nltk.sem.logic import Expression, Variable
from nltk.inference import Prover9

# Define the knowledge base
knowledge_base = [
    # Given facts
    Expression.fromstring('House(x, r) -> Nationality(x, e)'),
    Expression.fromstring('Pet(x, d) -> Nationality(x, s)'),
    Expression.fromstring('House(n, 1)'),
    Expression.fromstring('Color(x, g) & Color(y, i) & Adjacent(x, y) -> House(x, y)'),
    Expression.fromstring('(Candy(x, h) & Pet(x, f) & Adjacent(x, z)) -> (House(z, y) | House(x, y))'),
    Expression.fromstring('Candy(x, k) -> Color(x, y)'),
    Expression.fromstring('(Nationality(x, n) & Color(x, b)) -> (House(x - 1, y) | House(x + 1, y))'),
    Expression.fromstring('Candy(x, s) -> Pet(x, n)'),
    Expression.fromstring('Candy(x, sn) -> Drink(x, o)'),
    Expression.fromstring('Nationality(x, u) -> Drink(x, t)'),
    Expression.fromstring('Nationality(x, j) -> Candy(x, mw)'),
    Expression.fromstring('(Candy(x, k) & Pet(h, h)) -> (House(x - 1, y) | House(x + 1, y))'),
    Expression.fromstring('Drink(x, c) -> Color(x, g)'),
    Expression.fromstring('Drink(m, k)'),
    # Additional statements for adjacency
    Expression.fromstring('Adjacent(x, y) -> (x + 1 = y)'),
    Expression.fromstring('Adjacent(y, x) -> (y + 1 = x)')
]

# Create an instance of the Prover9 inference engine
prover = Prover9()

# Query for the zebra's house and the house where they drink water
query = Expression.fromstring('House(z, zebra) & Drink(w, water)')

# Perform the inference
result = prover.prove(query, knowledge_base)

# Check if the query is satisfied
if result:
    model = result.model()
    zebra_house = model.get('z')
    water_house = model.get('w')
    print("The zebra lives in house", zebra_house)
    print("They drink water in house", water_house)
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# UnexpectedTokenException                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:154, in LogicParser.parse(self, data, signature)
#     153 try:
# --> 154     result = self.process_next_expression(None)
#     155     if self.inRange(0):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:297, in LogicParser.process_next_expression(self, context)
#     293     raise UnexpectedTokenException(
#     294         self._currentIndex, tok, message="Expression expected."
#     295     )
# --> 297 return self.attempt_adjuncts(accum, context)
#
# ...

# %%
from nltk.sem.logic import Expression, Variable
from nltk.inference import Prover9

# Define the knowledge base
knowledge_base = [
    # Given facts
    Expression.fromstring('House(x, r) -> Nationality(x, e)'),
    Expression.fromstring('Pet(x, d) -> Nationality(x, s)'),
    Expression.fromstring('House(n, 1)'),
    Expression.fromstring('Color(x, g) & Color(y, i) & Adjacent(x, y) -> House(x, y)'),
    Expression.fromstring('(Candy(x, h) & Pet(x, f) & Adjacent(x, z)) -> (House(z, y) | House(x, y))'),
    Expression.fromstring('Candy(x, k) -> Color(x, y)'),
    Expression.fromstring('(Nationality(x, n) & Color(x, b) & Adjacent(x, y)) -> (House(y, z) | House(x, z))'),
    Expression.fromstring('Candy(x, s) -> Pet(x, n)'),
    Expression.fromstring('Candy(x, sn) -> Drink(x, o)'),
    Expression.fromstring('Nationality(x, u) -> Drink(x, t)'),
    Expression.fromstring('Nationality(x, j) -> Candy(x, mw)'),
    Expression.fromstring('(Candy(x, k) & Pet(h, h)) -> (House(x - 1, y) | House(x + 1, y))'),
    Expression.fromstring('Drink(x, c) -> Color(x, g)'),
    Expression.fromstring('Drink(m, k)'),
    # Additional statements for adjacency
    Expression.fromstring('Adjacent(x, y) -> (x = y + 1)'),
    Expression.fromstring('Adjacent(y, x) -> (y = x + 1)')
]

# Create an instance of the Prover9 inference engine
prover = Prover9()

# Query for the zebra's house and the house where they drink water
query = Expression.fromstring('House(z, zebra) & Drink(w, water)')

# Perform the inference
result = prover.prove(query, knowledge_base)

# Check if the query is satisfied
if result:
    model = result.model()
    zebra_house = model.get('z')
    water_house = model.get('w')
    print("The zebra lives in house", zebra_house)
    print("They drink water in house", water_house)
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# UnexpectedTokenException                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:154, in LogicParser.parse(self, data, signature)
#     153 try:
# --> 154     result = self.process_next_expression(None)
#     155     if self.inRange(0):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:297, in LogicParser.process_next_expression(self, context)
#     293     raise UnexpectedTokenException(
#     294         self._currentIndex, tok, message="Expression expected."
#     295     )
# --> 297 return self.attempt_adjuncts(accum, context)
#
# ...

# %%
from nltk.sem.logic import Expression, Variable
from nltk.inference import Prover9

# Define the knowledge base
knowledge_base = [
    # Given facts
    Expression.fromstring('House(x, r) & Nationality(x, e)'),
    Expression.fromstring('Pet(x, d) & Nationality(x, s)'),
    Expression.fromstring('House(1, n)'),
    Expression.fromstring('Color(x, g) & Color(y, i) & Adjacent(x, y) & House(x, y)'),
    Expression.fromstring('Candy(x, h) & Pet(x, f) & Adjacent(x, z) -> (House(z, y) | House(x, y))'),
    Expression.fromstring('Candy(x, k) & Color(x, y)'),
    Expression.fromstring('Nationality(x, n) & Color(x, b) & Adjacent(x, y) -> (House(y, z) | House(x, z))'),
    Expression.fromstring('Candy(x, s) & Pet(x, n)'),
    Expression.fromstring('Candy(x, sn) & Drink(x, o)'),
    Expression.fromstring('Nationality(x, u) & Drink(x, t)'),
    Expression.fromstring('Nationality(x, j) & Candy(x, mw)'),
    Expression.fromstring('Candy(x, k) & Pet(h, h) & House(x, y)'),
    Expression.fromstring('(x - 1 = y) | (x + 1 = y)'),
    Expression.fromstring('Drink(x, c) & Color(x, g)'),
    Expression.fromstring('Drink(m, k)'),
    # Additional statements for adjacency
    Expression.fromstring('Adjacent(x, y) -> (x = y + 1)'),
    Expression.fromstring('Adjacent(y, x) -> (y = x + 1)')
]

# Create an instance of the Prover9 inference engine
prover = Prover9()

# Query for the zebra's house and the house where they drink water
query = Expression.fromstring('House(z, zebra) & Drink(w, water)')

# Perform the inference
result = prover.prove(query, knowledge_base)

# Check if the query is satisfied
if result:
    model = result.model()
    zebra_house = model.get('z')
    water_house = model.get('w')
    print("The zebra lives in house", zebra_house)
    print("They drink water in house", water_house)
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# UnexpectedTokenException                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:154, in LogicParser.parse(self, data, signature)
#     153 try:
# --> 154     result = self.process_next_expression(None)
#     155     if self.inRange(0):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:290, in LogicParser.process_next_expression(self, context)
#     286     raise ExpectedMoreTokensException(
#     287         self._currentIndex + 1, message="Expression expected."
#     288     ) from e
# --> 290 accum = self.handle(tok, context)
#     292 if not accum:
#
# ...

# %%
from nltk.sem.logic import Expression, Variable
from nltk.inference import Prover9

# Define the knowledge base
knowledge_base = [
    # Given facts
    Expression.fromstring('House(x, r) & Nationality(x, e)'),
    Expression.fromstring('Pet(x, d) & Nationality(x, s)'),
    Expression.fromstring('House(1, n)'),
    Expression.fromstring('Color(x, g) & Color(y, i) & Adjacent(x, y) & House(x, y)'),
    Expression.fromstring('Candy(x, h) & Pet(x, f) & Adjacent(x, z) -> (House(z, y) | House(x, y))'),
    Expression.fromstring('Candy(x, k) & Color(x, y)'),
    Expression.fromstring('Nationality(x, n) & Color(x, b) & Adjacent(x, y) -> (House(y, z) | House(x, z))'),
    Expression.fromstring('Candy(x, s) & Pet(x, n)'),
    Expression.fromstring('Candy(x, sn) & Drink(x, o)'),
    Expression.fromstring('Nationality(x, u) & Drink(x, t)'),
    Expression.fromstring('Nationality(x, j) & Candy(x, mw)'),
    Expression.fromstring('Candy(x, k) & Pet(h, h) & ((x - 1) = y | (x + 1) = y)'),
    Expression.fromstring('Drink(x, c) & Color(x, g)'),
    Expression.fromstring('Drink(m, k)'),
    # Additional statements for adjacency
    Expression.fromstring('Adjacent(x, y) -> (x = y + 1)'),
    Expression.fromstring('Adjacent(y, x) -> (y = x + 1)')
]

# Create an instance of the Prover9 inference engine
prover = Prover9()

# Query for the zebra's house and the house where they drink water
query = Expression.fromstring('House(z, zebra) & Drink(w, water)')

# Perform the inference
result = prover.prove(query, knowledge_base)

# Check if the query is satisfied
if result:
    model = result.model()
    zebra_house = model.get('z')
    water_house = model.get('w')
    print("The zebra lives in house", zebra_house)
    print("They drink water in house", water_house)
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# UnexpectedTokenException                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:154, in LogicParser.parse(self, data, signature)
#     153 try:
# --> 154     result = self.process_next_expression(None)
#     155     if self.inRange(0):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:297, in LogicParser.process_next_expression(self, context)
#     293     raise UnexpectedTokenException(
#     294         self._currentIndex, tok, message="Expression expected."
#     295     )
# --> 297 return self.attempt_adjuncts(accum, context)
#
# ...

# %%
from nltk.sem.logic import Expression, Variable
from nltk.inference import Prover9

# Define the knowledge base
knowledge_base = [
    # Given facts
    Expression.fromstring('House(x, r) & Nationality(x, e)'),
    Expression.fromstring('Pet(x, d) & Nationality(x, s)'),
    Expression.fromstring('House(1, n)'),
    Expression.fromstring('Color(x, g) & Color(y, i) & Adjacent(x, y) & House(x, y)'),
    Expression.fromstring('Candy(x, h) & Pet(x, f) & Adjacent(x, z) -> (House(z, y) | House(x, y))'),
    Expression.fromstring('Candy(x, k) & Color(x, y)'),
    Expression.fromstring('Nationality(x, n) & Color(x, b) & Adjacent(x, y) -> (House(y, z) | House(x, z))'),
    Expression.fromstring('Candy(x, s) & Pet(x, n)'),
    Expression.fromstring('Candy(x, sn) & Drink(x, o)'),
    Expression.fromstring('Nationality(x, u) & Drink(x, t)'),
    Expression.fromstring('Nationality(x, j) & Candy(x, mw)'),
    Expression.fromstring('Candy(x, k) & Pet(h, h) & (Adjacent(x, y) | Adjacent(y, x))'),
    Expression.fromstring('Drink(x, c) & Color(x, g)'),
    Expression.fromstring('Drink(m, k)'),
    # Additional statements for adjacency
    Expression.fromstring('Adjacent(x, y) -> (x = y + 1)'),
    Expression.fromstring('Adjacent(y, x) -> (x = y + 1)')
]

# Create an instance of the Prover9 inference engine
prover = Prover9()

# Query for the zebra's house and the house where they drink water
query = Expression.fromstring('House(z, zebra) & Drink(w, water)')

# Perform the inference
result = prover.prove(query, knowledge_base)

# Check if the query is satisfied
if result:
    model = result.model()
    zebra_house = model.get('z')
    water_house = model.get('w')
    print("The zebra lives in house", zebra_house)
    print("They drink water in house", water_house)
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# UnexpectedTokenException                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:154, in LogicParser.parse(self, data, signature)
#     153 try:
# --> 154     result = self.process_next_expression(None)
#     155     if self.inRange(0):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:297, in LogicParser.process_next_expression(self, context)
#     293     raise UnexpectedTokenException(
#     294         self._currentIndex, tok, message="Expression expected."
#     295     )
# --> 297 return self.attempt_adjuncts(accum, context)
#
# ...

# %%
from nltk.sem.logic import Expression, Variable
from nltk.inference import Prover9

# Define the knowledge base
knowledge_base = [
    # Given facts
    Expression.fromstring('House(x, r) & Nationality(x, e)'),
    Expression.fromstring('Pet(x, d) & Nationality(x, s)'),
    Expression.fromstring('House(1, n)'),
    Expression.fromstring('Color(x, g) & Color(y, i) & Adjacent(x, y) & House(x, y)'),
    Expression.fromstring('Candy(x, h) & Pet(x, f) & Adjacent(x, z) -> (House(z, y) | House(x, y))'),
    Expression.fromstring('Candy(x, k) & Color(x, y)'),
    Expression.fromstring('Nationality(x, n) & Color(x, b) & Adjacent(x, y) -> (House(y, z) | House(x, z))'),
    Expression.fromstring('Candy(x, s) & Pet(x, n)'),
    Expression.fromstring('Candy(x, sn) & Drink(x, o)'),
    Expression.fromstring('Nationality(x, u) & Drink(x, t)'),
    Expression.fromstring('Nationality(x, j) & Candy(x, mw)'),
    Expression.fromstring('Candy(x, k) & Pet(h, h) & (Successor(x, y) | Successor(y, x))'),
    Expression.fromstring('Drink(x, c) & Color(x, g)'),
    Expression.fromstring('Drink(m, k)'),
    # Additional statements for adjacency
    Expression.fromstring('Successor(x, y) -> (x = y + 1)'),
    Expression.fromstring('Successor(y, x) -> (y = x + 1)')
]

# Create an instance of the Prover9 inference engine
prover = Prover9()

# Query for the zebra's house and the house where they drink water
query = Expression.fromstring('House(z, zebra) & Drink(w, water)')

# Perform the inference
result = prover.prove(query, knowledge_base)

# Check if the query is satisfied
if result:
    model = result.model()
    zebra_house = model.get('z')
    water_house = model.get('w')
    print("The zebra lives in house", zebra_house)
    print("They drink water in house", water_house)
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# UnexpectedTokenException                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:154, in LogicParser.parse(self, data, signature)
#     153 try:
# --> 154     result = self.process_next_expression(None)
#     155     if self.inRange(0):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\nltk\sem\logic.py:297, in LogicParser.process_next_expression(self, context)
#     293     raise UnexpectedTokenException(
#     294         self._currentIndex, tok, message="Expression expected."
#     295     )
# --> 297 return self.attempt_adjuncts(accum, context)
#
# ...

# %%
from nltk.sem.logic import Expression, Variable
from nltk.inference import Prover9

# Define the knowledge base
knowledge_base = [
    # Given facts
    Expression.fromstring('House(x, r) & Nationality(x, e)'),
    Expression.fromstring('Pet(x, d) & Nationality(x, s)'),
    Expression.fromstring('House(1, n)'),
    Expression.fromstring('Color(x, g) & Color(y, i) & Adjacent(x, y) & House(x, y)'),
    Expression.fromstring('Candy(x, h) & Pet(x, f) & Adjacent(x, z) -> (House(z, y) | House(x, y))'),
    Expression.fromstring('Candy(x, k) & Color(x, y)'),
    Expression.fromstring('Nationality(x, n) & Color(x, b) & Adjacent(x, y) -> (House(y, z) | House(x, z))'),
    Expression.fromstring('Candy(x, s) & Pet(x, n)'),
    Expression.fromstring('Candy(x, sn) & Drink(x, o)'),
    Expression.fromstring('Nationality(x, u) & Drink(x, t)'),
    Expression.fromstring('Nationality(x, j) & Candy(x, mw)'),
    Expression.fromstring('Candy(x, k) & Pet(h, h)'),
    Expression.fromstring('Drink(x, c) & Color(x, g)'),
    Expression.fromstring('Drink(m, k)'),
    # Additional statements for adjacency
    Expression.fromstring('Adjacent(x, y) & Successor(y, x)'),
    Expression.fromstring('Adjacent(y, x) & Successor(x, y)')
]

# Define the arithmetic expression (x = y + 1) using logical operators
expression = Expression.fromstring('(Successor(y, x) & Successor(z, y) & Successor(x, z))')

# Create an instance of the Prover9 inference engine
prover = Prover9()

# Query for the zebra's house and the house where they drink water
query = Expression.fromstring('House(z, zebra) & Drink(w, water)')

# Add the modified arithmetic expression to the knowledge base
knowledge_base.append(expression)

# Perform the inference
result = prover.prove(query, knowledge_base)

# Check if the query is satisfied
if result:
    model = result.model()
    zebra_house = model.get('z')
    water_house = model.get('w')
    print("The zebra lives in house", zebra_house)
    print("They drink water in house", water_house)
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# c:\Users\vivek\Desktop\sem4\IT255-Ai\zebra.ipynb Cell 19 in 3
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X24sZmlsZQ%3D%3D?line=35'>36</a> knowledge_base.append(expression)
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X24sZmlsZQ%3D%3D?line=37'>38</a> # Perform the inference
# ---> <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X24sZmlsZQ%3D%3D?line=38'>39</a> result = prover.prove(query, knowledge_base)
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X24sZmlsZQ%3D%3D?line=40'>41</a> # Check if the query is satisfied
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X24sZmlsZQ%3D%3D?line=41'>42</a> if result:
#
# ...

# %%
from constraint import Problem, AllDifferentConstraint

def solve_zebra_puzzle():
    problem = Problem()

    # Define the variables and their domains
    colors = ["Red", "Green", "Ivory", "Yellow", "Blue"]
    houses = range(1, 6)
    nationalities = ["Englishman", "Spaniard", "Ukrainian", "Norwegian", "Japanese"]
    drinks = ["Coffee", "Tea", "Milk", "Orange juice", "Water"]
    pets = ["Dog", "Snails", "Fox", "Horse", "Zebra"]
    candies = ["Kit Kat", "Smarties", "Snickers", "Milky Way", "Hershey's"]

    problem.addVariables(houses, colors)
    problem.addVariables(houses, nationalities)
    problem.addVariables(houses, drinks)
    problem.addVariables(houses, pets)
    problem.addVariables(houses, candies)

    # Add constraints
    problem.addConstraint(AllDifferentConstraint(), houses)

    # Define other constraints based on the puzzle clues

    # ...

    # Solve the problem
    solutions = problem.getSolutions()
    return solutions

solutions = solve_zebra_puzzle()

if solutions:
    # Print the solution
    for solution in solutions:
        for house in range(1, 6):
            print(f"House {house}:")
            for attribute in solution:
                if attribute.startswith("House") and solution[attribute] == house:
                    print(f"{attribute}: {solution[attribute]}")
        print("-----------")
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\vivek\Desktop\sem4\IT255-Ai\zebra.ipynb Cell 20 in 3
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X25sZmlsZQ%3D%3D?line=27'>28</a>     solutions = problem.getSolutions()
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X25sZmlsZQ%3D%3D?line=28'>29</a>     return solutions
# ---> <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X25sZmlsZQ%3D%3D?line=30'>31</a> solutions = solve_zebra_puzzle()
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X25sZmlsZQ%3D%3D?line=32'>33</a> if solutions:
#      <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X25sZmlsZQ%3D%3D?line=33'>34</a>     # Print the solution
# ...

# %%
from nltk.sem.logic import Expression, Variable
from nltk.integrate import ResolutionProver
import subprocess

# Define the knowledge base
knowledge_base = [
    # Given facts
    Expression.fromstring('House(x, r) & Nationality(x, e)'),
    Expression.fromstring('Pet(x, d) & Nationality(x, s)'),
    Expression.fromstring('House(1, n)'),
    Expression.fromstring('Color(x, g) & Color(y, i) & Adjacent(x, y) & House(x, y)'),
    Expression.fromstring('Candy(x, h) & Pet(x, f) & Adjacent(x, z) -> (House(z, y) | House(x, y))'),
    Expression.fromstring('Candy(x, k) & Color(x, y)'),
    Expression.fromstring('Nationality(x, n) & Color(x, b) & Adjacent(x, y) -> (House(y, z) | House(x, z))'),
    Expression.fromstring('Candy(x, s) & Pet(x, n)'),
    Expression.fromstring('Candy(x, sn) & Drink(x, o)'),
    Expression.fromstring('Nationality(x, u) & Drink(x, t)'),
    Expression.fromstring('Nationality(x, j) & Candy(x, mw)'),
    Expression.fromstring('Candy(x, k) & Pet(h, h)'),
    Expression.fromstring('Drink(x, c) & Color(x, g)'),
    Expression.fromstring('Drink(m, k)'),
    # Additional statements for adjacency
    Expression.fromstring('Adjacent(x, y) & Successor(y, x)'),
    Expression.fromstring('Adjacent(y, x) & Successor(x, y)')
]

# Define the arithmetic expression (x = y + 1) using logical operators
expression = Expression.fromstring('(Successor(y, x) & Successor(z, y) & Successor(x, z))')

# Query for the zebra's house and the house where they drink water
query = Expression.fromstring('House(z, zebra) & Drink(w, water)')

# Add the modified arithmetic expression to the knowledge base
knowledge_base.append(expression)

# Combine the knowledge base and query into a single expression
combined_expression = Expression.fromstring('(' + ', '.join(str(expr) for expr in knowledge_base) + ') & ' + str(query))

# Convert the expression to a string in NuSMV syntax
nusmv_input = combined_expression.to_nusmv()

# Save the NuSMV input to a file
with open('nusmv_input.smv', 'w') as file:
    file.write(nusmv_input)

# Run NuSMV to check the satisfiability of the input
output = subprocess.check_output(['NuSMV', 'nusmv_input.smv'])

# Check the output for a model satisfying the expression
if 'is false' not in output.decode():
    # Parse the model from the output
    model_lines = output.decode().split('-> Specification')
    model_str = model_lines[1].split('-- invariant')[0].strip()
    model_dict = eval(model_str)

    zebra_house = model_dict['z']
    water_house = model_dict['w']

    print("The zebra lives in house", zebra_house)
    print("They drink water in house", water_house)
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\vivek\Desktop\sem4\IT255-Ai\zebra.ipynb Cell 21 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> from nltk.sem.logic import Expression, Variable
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> from nltk.integrate import ResolutionProver
#       <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a> import subprocess
#       <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a> # Define the knowledge base
#
# ModuleNotFoundError: No module named 'nltk.integrate'

# %%
from nltk.sem.logic import Expression, Variable
from pyclp.fd import clpfd
from pyclp.logic import Structure, Term, unify, PLVar

# Define the knowledge base
knowledge_base = [
    # Given facts
    Expression.fromstring('House(x, r) & Nationality(x, e)'),
    Expression.fromstring('Pet(x, d) & Nationality(x, s)'),
    Expression.fromstring('House(1, n)'),
    Expression.fromstring('Color(x, g) & Color(y, i) & Adjacent(x, y) & House(x, y)'),
    Expression.fromstring('Candy(x, h) & Pet(x, f) & Adjacent(x, z) -> (House(z, y) | House(x, y))'),
    Expression.fromstring('Candy(x, k) & Color(x, y)'),
    Expression.fromstring('Nationality(x, n) & Color(x, b) & Adjacent(x, y) -> (House(y, z) | House(x, z))'),
    Expression.fromstring('Candy(x, s) & Pet(x, n)'),
    Expression.fromstring('Candy(x, sn) & Drink(x, o)'),
    Expression.fromstring('Nationality(x, u) & Drink(x, t)'),
    Expression.fromstring('Nationality(x, j) & Candy(x, mw)'),
    Expression.fromstring('Candy(x, k) & Pet(h, h)'),
    Expression.fromstring('Drink(x, c) & Color(x, g)'),
    Expression.fromstring('Drink(m, k)'),
    # Additional statements for adjacency
    Expression.fromstring('Adjacent(x, y) & Successor(y, x)'),
    Expression.fromstring('Adjacent(y, x) & Successor(x, y)')
]

# Define the arithmetic expression (x = y + 1) using logical operators
expression = Expression.fromstring('(Successor(y, x) & Successor(z, y) & Successor(x, z))')

# Query for the zebra's house and the house where they drink water
query = Expression.fromstring('House(z, zebra) & Drink(w, water)')

# Create the PyCLP environment
env = clpfd.Environment()

# Define the knowledge base as PyCLP facts
for expr in knowledge_base:
    env.asserta(env.to_prolog(expr))

# Add the modified arithmetic expression as a PyCLP fact
env.asserta(env.to_prolog(expression))

# Query the knowledge base using PyCLP
solution = env.query(env.to_prolog(query))

# Check if a solution is found
if solution:
    model = solution.next()
    zebra_house = model["z"].value
    water_house = model["w"].value

    print("The zebra lives in house", zebra_house)
    print("They drink water in house", water_house)
else:
    print("No solution found.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\vivek\Desktop\sem4\IT255-Ai\zebra.ipynb Cell 22 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> from nltk.sem.logic import Expression, Variable
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> from pyclp.fd import clpfd
#       <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a> from pyclp.logic import Structure, Term, unify, PLVar
#       <a href='vscode-notebook-cell:/c%3A/Users/vivek/Desktop/sem4/IT255-Ai/zebra.ipynb#X30sZmlsZQ%3D%3D?line=4'>5</a> # Define the knowledge base
#
# ModuleNotFoundError: No module named 'pyclp'
