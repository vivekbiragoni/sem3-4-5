# %% [markdown]
# Shape and Variation analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("FuelConsumptionCo2.csv")
df
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0             AS5        Z                   9.9                  6.7
# 1              M6        Z                  11.2                  7.7
# 2             AV7        Z                   6.0                  5.8
# 3             AS6        Z                  12.7                  9.1
# 4             AS6        Z                  12.1                  8.7
# ...           ...      ...                   ...                  ...
# 1062          AS6        X                  13.4                  9.8
# 1063          AS6        X                  13.2                  9.5
# 1064          AS6        X                  13.4                  9.8
# 1065          AS6        X                  12.9                  9.3
# 1066          AS6        X                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                      8.5                        33           196
# 1                      9.6                        29           221
# 2                      5.9                        48           136
# 3                     11.1                        25           255
# 4                     10.6                        27           244
# ...                    ...                       ...           ...
# 1062                  11.8                        24           271
# 1063                  11.5                        25           264
# 1064                  11.8                        24           271
# 1065                  11.3                        25           260
# 1066                  12.8                        22           294
#
# [1067 rows x 13 columns]

# %%
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# 1                   9.6                        29           221
# 2                   5.9                        48           136
# 3                  11.1                        25           255
# 4                  10.6                        27           244

# %%
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 108.5+ KB

# %%
cdf = df["CO2EMISSIONS"]
vvb = df["CYLINDERS"]

# %%
type(cdf)
# Out:
# pandas.core.series.Series

# %%
cdf
# Out:
# 0       196
# 1       221
# 2       136
# 3       255
# 4       244
#        ...
# 1062    271
# 1063    264
# 1064    271
# 1065    260
# 1066    294
# Name: CO2EMISSIONS, Length: 1067, dtype: int64

# %%
plt.plot(cdf)

# %%
cdf.mean()
# Out:
# 256.2286785379569

# %%
cdf.median()
# Out:
# 251.0

# %% [markdown]
# Degrees of freedom refer to the number of independent pieces
# of information that are used to calculate a statistic

# %%
# standard deviation 
# default ddof = 1       
# divded by n - 1
cdf.std()
# Out:
# 63.372304442800065

# %%
# standard deviation 
# ddof = 0
# divded by n 
cdf.std(ddof=0)
# Out:
# 63.34260099404252

# %%
# variance with ddof = 0
# sum((x_i - x_mean)^2) / n
cdf.var(ddof = 0)
# Out:
# 4012.2851006904766

# %%
# variance with ddof = 1
# sum((x_i - x_mean)^2) / (n-1)
cdf.var(ddof = 1)
# Out:
# 4016.048970390937

# %%
# mean (average) absolute deviation
cdf.mad()
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_18724\3109426883.py:2: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   cdf.mad()
# 51.04539613470135

# %%
plt.plot(vvb, cdf )

# %%
plt.scatter(df.FUELCONSUMPTION_COMB, df.CO2EMISSIONS, color = 'blue')
plt.xlabel("FUELCONSUMPTION_COMB")
plt.ylabel("Emission")
plt.show()

# %%
plt.bar(cdf, vvb)
# Out:
# <BarContainer object of 1067 artists>

# %%
sns.displot(cdf)

# %%
cdf.plot(kind="hist")
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# from the visual analysis we get to know that the chosen data is almost a positively skewed

# %% [markdown]
# Skewness

# %%
cdf.skew()
# Out:
# 0.5195146330615628

# %%
# calculate the third moment of the distribution
third_moment = np.sum((cdf - cdf.mean())**3) / len(cdf)

# calculate the standard deviation of the distribution
std_dev = np.std(cdf, ddof=0)

# calculate the moment of coefficient of skewness
moment_of_coefficient_of_skewness = third_moment / (std_dev**3)

print(moment_of_coefficient_of_skewness)
# Out:
# 0.5187840084529483

# %% [markdown]
# We implemented the above code to find the moent of coefficient of skewness which gives a (+ve) value and this confirms our earlier assumptions from visual analysis of histogram that, this is a (+ve)ly skewed data.
#
# ==> Data is Modedrately skewed.

# %%
cdf.kurtosis()
# Out:
# -0.10955312596150169

# %% [markdown]
# We get a negative kurtosis, it means that our distribution is flatter and has lighter tails than a normal distribution. This type of distribution is called a platykurtic distribution.

# %% [markdown]
# **Outliers and BoxPlots**

# %% [markdown]
# Create a box plot using Matplotlib's boxplot function:

# %%
plt.boxplot(cdf)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1efa5c2e5f0>,
#   <matplotlib.lines.Line2D at 0x1efa5c2e890>],
#  'caps': [<matplotlib.lines.Line2D at 0x1efa5c2eb30>,
#   <matplotlib.lines.Line2D at 0x1efa5c2edd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1efa5c2e350>],
#  'medians': [<matplotlib.lines.Line2D at 0x1efa5c2f070>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1efa5c2f310>],
#  'means': []}

# %% [markdown]
# To find outliers, we can use the interquartile range (IQR) method. First, calculate the IQR:

# %%
q1, q3 = np.percentile(cdf, [25, 75])
iqr = q3 - q1
iqr
# Out:
# 87.0

# %% [markdown]
# Then, define the upper and lower bounds:

# %%
upper_bound = q3 + (1.5 * iqr)
lower_bound = q1 - (1.5 * iqr)

# %% [markdown]
# Finally, find any data points that fall outside the bounds:

# %%
outliers = [x for x in cdf if x < lower_bound or x > upper_bound]
print("Outliers:", outliers)
# Out:
# Outliers: [437, 432, 435, 488, 432, 435]

# %% [markdown]
# **Summary:**
# Mean = 256.2286785379569
# Median = 251.0
# std deviation = 63.372304442800065
# varaince = 4016.048970390937
# mean absolute deviation=51.04539613470135
# Skewness = 0.5187840084529483,
# Kurtosis = -0.10955312596150169
# (+ve)ly skewed data and is platykurtic distribution.
